# %%
# Importando os pacotes

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Lendo os arquivos

sample = pd.read_csv('datasets/sample_submission.csv')
train = pd.read_csv('datasets/train.csv')
test = pd.read_csv('datasets/test.csv')

# %%
print("Skewness: " + str(train['SalePrice'].skew())) # é o grau de distorção da curva simetrica.
print("Kurtosis: " + str(train['SalePrice'].kurt()))
# Out:
# Skewness: 1.8828757597682129
# Kurtosis: 6.536281860064529

# %%
(train.corr()**2)["SalePrice"].sort_values(ascending = False)[1:]
# Out:
# OverallQual      0.625652
# GrLivArea        0.502149
# GarageCars       0.410124
# GarageArea       0.388667
# TotalBsmtSF      0.376481
# 1stFlrSF         0.367057
# FullBath         0.314344
# TotRmsAbvGrd     0.284860
# YearBuilt        0.273422
# YearRemodAdd     0.257151
# GarageYrBlt      0.236548
# MasVnrArea       0.228000
# Fireplaces       0.218023
# BsmtFinSF1       0.149320
# LotFrontage      0.123763
# WoodDeckSF       0.105244
# 2ndFlrSF         0.101974
# OpenPorchSF      0.099765
# HalfBath         0.080717
# LotArea          0.069613
# BsmtFullBath     0.051585
# BsmtUnfSF        0.046001
# BedroomAbvGr     0.028296
# KitchenAbvGr     0.018471
# EnclosedPorch    0.016532
# ScreenPorch      0.012420
# PoolArea         0.008538
# MSSubClass       0.007104
# OverallCond      0.006062
# MoSold           0.002156
# 3SsnPorch        0.001988
# YrSold           0.000837
# LowQualFinSF     0.000656
# Id               0.000480
# MiscVal          0.000449
# ...

# %%
sns.scatterplot(train.OverallQual, train.SalePrice)

# %%
sns.scatterplot(train.GrLivArea, train.SalePrice)

# %%
sns.scatterplot(train.GarageCars, train.SalePrice)

# %%
sns.scatterplot(train.GarageArea, train.SalePrice)

# %%
# deletando os dois valores outiliers
train = train[train.GrLivArea < 4500]
train.reset_index(drop = True, inplace = True)

previous_train = train.copy()

# %%
sns.scatterplot(previous_train.GrLivArea, previous_train.SalePrice)

# %%
plt.subplots(figsize = (15,10))
sns.regplot(previous_train.GrLivArea, previous_train.SalePrice)
